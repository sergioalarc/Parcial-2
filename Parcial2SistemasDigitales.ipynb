# %%
# ==========================================
# CHATBOT DE SISTEMAS DIGITALES PARCIAL 2
# ==========================================

import requests
import ipywidgets as widgets
from IPython.display import display

API_KEY = "sk-2d5996dc3b04479e9dacbf5d0085ce60"
API_URL = "https://api.deepseek.com/v1/chat/completions"

# ==========================================
# FUNCIÓN PARA LLAMAR A LA API
# ==========================================
def enviar_mensaje_api(mensaje, modelo="deepseek-chat"):

    headers = {
        "Authorization": f"Bearer {API_KEY}",
        "Content-Type": "application/json"
    }

    data = {
        "model": modelo,
        "messages": [
            {
                "role": "system",
                "content": (
                    "Eres un experto en sistemas digitales y semiconductores en el contexto actual (año 2026). "
                    "Analizas la industria de semiconductores, explicas su impacto en los sistemas digitales "
                    "y relacionas empresas líderes con avances tecnológicos. "

                    "También respondes sobre aplicaciones en educación, innovación tecnológica, "
                    "impacto de proyectos y tendencias futuras. "

                    "Debes poder responder específicamente sobre:"
                    "- Situación de los semiconductores en 2026"
                    "- Empresas más importantes del sector"
                    "- Impacto en sistemas digitales"
                    "- Innovación en educación"
                    "- Proyectos tecnológicos educativos"
                    "- Futuro de los sistemas digitales"

                    "Mantén respuestas claras, bien estructuradas y educativas."
                )
            },
            {"role": "user", "content": mensaje}
        ],
        "temperature": 0.6
    }

    try:
        response = requests.post(API_URL, headers=headers, json=data)
        response.raise_for_status()
        return response.json()['choices'][0]['message']['content']

    except Exception as e:
        return f"Error en la API: {e}"


# ==========================================
# TEMAS VÁLIDOS
# ==========================================
temas_validos = [
    "and", "or", "xor", "xnor", "nand", "nor", "not",
    "compuerta", "logica", "lógica", "booleano",
    "flip flop", "jk", "sr", "d", "t",
    "karnaugh", "mux", "multiplexor", "demux",
    "contador", "registro", "sumador",
    "binario", "codificador", "decodificador",
    "secuencial", "combinacional",
    "semiconductores", "empresas", "educacion",
    "innovacion", "proyectos", "futuro", "industria"
]


def es_tema_valido(pregunta):
    pregunta = pregunta.lower()
    return any(tema in pregunta for tema in temas_validos)


# ==========================================
# RESPUESTAS LOCALES
# ==========================================
respuestas_locales = {

    # 🔹 ELECTRÓNICA DIGITAL (mejoradas)
    "and": """La compuerta AND es un dispositivo lógico que solo produce una salida en nivel alto (1) cuando todas sus entradas también están en nivel alto.
     Esto significa que funciona como una condición estricta donde todas las variables deben cumplirse simultáneamente. Es muy utilizada en circuitos donde
     se requiere verificar múltiples condiciones al mismo tiempo.""",

    "or": """La compuerta OR genera una salida en nivel alto cuando al menos una de sus entradas está en nivel alto. Esto la hace útil en situaciones donde
    basta con que se cumpla una sola condición para activar una acción dentro del sistema digital.""",

    "xor": """La compuerta XOR, también conocida como OR exclusiva, produce una salida en nivel alto únicamente cuando las entradas son diferentes entre sí.
    Es ampliamente utilizada en sistemas de suma binaria y en circuitos donde se requiere detectar diferencias entre señales.""",

    "flip flop": """El flip-flop es un circuito secuencial fundamental que tiene la capacidad de almacenar un bit de información. A diferencia de los circuitos
     combinacionales, su salida depende no solo de las entradas actuales, sino también de su estado previo. Es la base de elementos como registros,
     contadores y memorias digitales.""",

    "karnaugh": """El mapa de Karnaugh es una herramienta gráfica que permite simplificar funciones booleanas de manera visual. Su principal ventaja es que
    reduce la cantidad de compuertas necesarias en un circuito, optimizando así el diseño y mejorando la eficiencia del sistema digital.""",

    "contador": """Un contador es un circuito secuencial diseñado para registrar el número de eventos o pulsos de reloj que recibe. Dependiendo de su
    configuración, puede contar hacia arriba, hacia abajo o en ambas direcciones, y es fundamental en aplicaciones como relojes digitales, temporizadores
    y sistemas de control.""" ,


    # 🔹 NUEVAS RESPUESTAS EN TEXTO (CLAVE DEL PARCIAL)

    "semiconductores 2026": """En el año 2026, la industria de los semiconductores se ha consolidado como uno de los pilares fundamentales del desarrollo
    tecnológico global. El avance en la fabricación de chips con tecnologías de 3 nanómetros y menores ha permitido crear dispositivos mucho más rápidos,
    eficientes y con menor consumo energético. Además, el crecimiento de la inteligencia artificial ha impulsado el desarrollo de procesadores especializados,
    como GPUs y aceleradores de IA, que optimizan tareas complejas.

Este avance impacta directamente en los sistemas digitales, ya que permite diseñar circuitos más compactos, con mayor capacidad de procesamiento y mejor
rendimiento en aplicaciones como centros de datos, dispositivos móviles, automatización industrial y sistemas embebidos.""",

    "empresas": """Dentro del sector de los semiconductores, existen varias empresas que lideran la innovación y el desarrollo tecnológico a nivel mundial.
    Entre ellas destacan NVIDIA, que ha revolucionado el procesamiento para inteligencia artificial; Intel, que continúa siendo clave en el diseño y
    fabricación de procesadores; TSMC, considerada la mayor fabricante de chips del mundo; Samsung, con fuerte presencia en memorias y fabricación avanzada;
    y AMD, reconocida por sus procesadores de alto rendimiento.

El impacto de estas empresas en los sistemas digitales es significativo, ya que sus avances permiten el desarrollo de dispositivos más potentes,
eficientes y accesibles, impulsando áreas como la computación, la automatización y la electrónica de consumo.""",

    "educacion innovacion": """La innovación en la educación gracias a los sistemas digitales y los semiconductores ha transformado la manera en
    que se enseña y se aprende. Actualmente, los estudiantes pueden acceder a simuladores digitales, laboratorios virtuales y plataformas interactivas
    que facilitan la comprensión de conceptos complejos sin necesidad de equipos físicos costosos.

Además, el uso de tecnologías como microcontroladores, FPGA y herramientas basadas en inteligencia artificial permite una enseñanza más práctica y personalizada.
Esto no solo mejora la calidad del aprendizaje, sino que también prepara a los estudiantes para enfrentar los desafíos tecnológicos del mundo moderno.""",

    "proyectos educacion": """En el ámbito educativo, los proyectos basados en sistemas digitales han cobrado gran relevancia, ya que permiten
    aplicar conocimientos teóricos en situaciones prácticas. Ejemplos de estos proyectos incluyen el desarrollo de robots educativos, sistemas automatizados
    con Arduino o Raspberry Pi, y el diseño de circuitos digitales para resolver problemas reales.

El impacto de estos proyectos es muy positivo, ya que fomentan el pensamiento lógico, la creatividad y la resolución de problemas. Además, ayudan a los
estudiantes a desarrollar habilidades técnicas que son altamente demandadas en la industria tecnológica actual.""",

    "futuro": """El futuro de los sistemas digitales y los semiconductores apunta hacia tecnologías cada vez más avanzadas e integradas. Se espera un
    crecimiento significativo en áreas como la computación cuántica, los chips neuromórficos inspirados en el cerebro humano y la expansión masiva del
    Internet de las Cosas (IoT).

Estos avances permitirán la creación de sistemas más inteligentes, autónomos y eficientes, capaces de procesar grandes cantidades de información en tiempo real.
En consecuencia, los sistemas digitales seguirán siendo un elemento clave en la transformación digital de la sociedad y en el desarrollo de nuevas soluciones tecnológicas."""
}


# ==========================================
# LÓGICA DEL CHATBOT
# ==========================================
def responder(pregunta):
    pregunta_lower = pregunta.lower()

    if "hola" in pregunta_lower:
        return "Hola, soy un chatbot experto en sistemas digitales y semiconductores 2026."


    if "semiconductores" in pregunta_lower and "2026" in pregunta_lower:
        return respuestas_locales["semiconductores 2026"]

    if "empresas" in pregunta_lower:
        return respuestas_locales["empresas"]

    if "educacion" in pregunta_lower and "innovacion" in pregunta_lower:
        return respuestas_locales["educacion innovacion"]

    if "proyectos" in pregunta_lower:
        return respuestas_locales["proyectos educacion"]

    if "futuro" in pregunta_lower:
        return respuestas_locales["futuro"]


    if not es_tema_valido(pregunta_lower):
        return "Este chatbot solo responde sobre sistemas digitales y semiconductores."


    for clave, respuesta in respuestas_locales.items():
        if clave in pregunta_lower:
            return respuesta


    return enviar_mensaje_api(pregunta)


# ==========================================
# INTERFAZ GRÁFICA
# ==========================================
entrada = widgets.Text(
    placeholder='Escribe tu pregunta...',
    description='Tú:',
    layout=widgets.Layout(width='80%')
)

boton = widgets.Button(
    description="Enviar",
    button_style='success'
)

salida = widgets.Output()


def al_hacer_click(b):
    with salida:
        salida.clear_output()
        respuesta = responder(entrada.value)
        print("Bot:", respuesta)


boton.on_click(al_hacer_click)

display(entrada, boton, salida)
# Out:
# Text(value='', description='Tú:', layout=Layout(width='80%'), placeholder='Escribe tu pregunta...')
# Button(button_style='success', description='Enviar', style=ButtonStyle())
# Output()
